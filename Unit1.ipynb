# %% [markdown]
# <a href="https://colab.research.google.com/github/lyj12h/studyML/blob/main/Study_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data_root="https://github.com/ageron/data/raw/main/"

# %%
lifesat=pd.read_csv(data_root+"lifesat/lifesat.csv")
x=lifesat[["GDP per capita (USD)"]].values
y=lifesat[["Life satisfaction"]].values

# %% [markdown]
# Linear Regression

# %%
lifesat.plot(kind="scatter",x="GDP per capita (USD)",y="Life satisfaction",grid=True)
plt.axis([23_500,62_500, 4,9])
plt.show()

# %%
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
plt.plot(x,model.predict(x),color="red")
plt.scatter(x,y)
plt.show()

# %%
x_new=[[37_655.2]]
print(model.predict(x_new))
# Out:
# [[6.30165767]]

# %% [markdown]
# K-nearest neighbors

# %%
from sklearn.neighbors import KNeighborsRegressor
model=KNeighborsRegressor(n_neighbors=3)
model.fit(x,y)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
plt.plot(x,model.predict(x),color="red")
plt.scatter(x,y)
plt.show()
